# %% [markdown]
# # Dados dos Condutores ACSR para Linha de Transmissão Aérea

# %%
# bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## informações dos condutores

# %%
df = pd.read_csv('condutores-acsr.csv', 
                 usecols=["Nome comercial", "Diametro cond. (mm)", "Ampacidade (A)","Rmax CC@20C (Ohm/km)", "Rmax CA @ 60 Hz 75C (Ohm/km)"])
# visualizando
# df.head(df.shape[0])
df.head(30)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv('condutores-acsr.csv',
#       2                  usecols=["Nome comercial", "Diametro cond. (mm)", "Ampacidade (A)","Rmax CC@20C (Ohm/km)", "Rmax CA @ 60 Hz 75C (Ohm/km)"])
#       3 # visualizando
#       4 # df.head(df.shape[0])
#       5 df.head(30)
#
# ...
